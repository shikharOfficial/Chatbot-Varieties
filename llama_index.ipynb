# %%
# %pip install llama-index transformers accelerate bitsandbytes pypdf llama_index llama-index-llms-huggingface
# Out:
# Requirement already satisfied: llama-index in ./chatbot-env/lib/python3.10/site-packages (0.10.61)
# Requirement already satisfied: transformers in ./chatbot-env/lib/python3.10/site-packages (4.43.3)
# Requirement already satisfied: accelerate in ./chatbot-env/lib/python3.10/site-packages (0.33.0)
# Requirement already satisfied: bitsandbytes in ./chatbot-env/lib/python3.10/site-packages (0.43.3)
# Requirement already satisfied: pypdf in ./chatbot-env/lib/python3.10/site-packages (4.3.1)
# Requirement already satisfied: llama-index-llms-huggingface in ./chatbot-env/lib/python3.10/site-packages (0.2.5)
# Requirement already satisfied: llama-index-core==0.10.61 in ./chatbot-env/lib/python3.10/site-packages (from llama-index) (0.10.61)
# Requirement already satisfied: llama-index-embeddings-openai<0.2.0,>=0.1.5 in ./chatbot-env/lib/python3.10/site-packages (from llama-index) (0.1.11)
# Requirement already satisfied: llama-index-multi-modal-llms-openai<0.2.0,>=0.1.3 in ./chatbot-env/lib/python3.10/site-packages (from llama-index) (0.1.8)
# Requirement already satisfied: llama-index-legacy<0.10.0,>=0.9.48 in ./chatbot-env/lib/python3.10/site-packages (from llama-index) (0.9.48)
# Requirement already satisfied: llama-index-program-openai<0.2.0,>=0.1.3 in ./chatbot-env/lib/python3.10/site-packages (from llama-index) (0.1.7)
# Requirement already satisfied: llama-index-readers-file<0.2.0,>=0.1.4 in ./chatbot-env/lib/python3.10/site-packages (from llama-index) (0.1.32)
# Requirement already satisfied: llama-index-readers-llama-parse>=0.1.2 in ./chatbot-env/lib/python3.10/site-packages (from llama-index) (0.1.6)
# Requirement already satisfied: llama-index-llms-openai<0.2.0,>=0.1.27 in ./chatbot-env/lib/python3.10/site-packages (from llama-index) (0.1.27)
# Requirement already satisfied: llama-index-agent-openai<0.3.0,>=0.1.4 in ./chatbot-env/lib/python3.10/site-packages (from llama-index) (0.2.9)
# Requirement already satisfied: llama-index-cli<0.2.0,>=0.1.2 in ./chatbot-env/lib/python3.10/site-packages (from llama-index) (0.1.13)
# Requirement already satisfied: llama-index-question-gen-openai<0.2.0,>=0.1.2 in ./chatbot-env/lib/python3.10/site-packages (from llama-index) (0.1.3)
# Requirement already satisfied: llama-index-indices-managed-llama-cloud>=0.2.0 in ./chatbot-env/lib/python3.10/site-packages (from llama-index) (0.2.7)
# Requirement already satisfied: pandas in ./chatbot-env/lib/python3.10/site-packages (from llama-index-core==0.10.61->llama-index) (2.2.2)
# Requirement already satisfied: tiktoken>=0.3.3 in ./chatbot-env/lib/python3.10/site-packages (from llama-index-core==0.10.61->llama-index) (0.7.0)
# Requirement already satisfied: networkx>=3.0 in ./chatbot-env/lib/python3.10/site-packages (from llama-index-core==0.10.61->llama-index) (3.3)
# Requirement already satisfied: dataclasses-json in ./chatbot-env/lib/python3.10/site-packages (from llama-index-core==0.10.61->llama-index) (0.5.14)
# Requirement already satisfied: deprecated>=1.2.9.3 in ./chatbot-env/lib/python3.10/site-packages (from llama-index-core==0.10.61->llama-index) (1.2.14)
# Requirement already satisfied: numpy<2.0.0 in ./chatbot-env/lib/python3.10/site-packages (from llama-index-core==0.10.61->llama-index) (1.26.4)
# Requirement already satisfied: wrapt in ./chatbot-env/lib/python3.10/site-packages (from llama-index-core==0.10.61->llama-index) (1.16.0)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.2.0 in ./chatbot-env/lib/python3.10/site-packages (from llama-index-core==0.10.61->llama-index) (8.5.0)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in ./chatbot-env/lib/python3.10/site-packages (from llama-index-core==0.10.61->llama-index) (3.10.0)
# Requirement already satisfied: openai>=1.1.0 in ./chatbot-env/lib/python3.10/site-packages (from llama-index-core==0.10.61->llama-index) (1.39.0)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in ./chatbot-env/lib/python3.10/site-packages (from llama-index-core==0.10.61->llama-index) (3.8.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in ./chatbot-env/lib/python3.10/site-packages (from llama-index-core==0.10.61->llama-index) (4.12.2)
# Requirement already satisfied: pillow>=9.0.0 in ./chatbot-env/lib/python3.10/site-packages (from llama-index-core==0.10.61->llama-index) (10.4.0)
# Requirement already satisfied: httpx in ./chatbot-env/lib/python3.10/site-packages (from llama-index-core==0.10.61->llama-index) (0.27.0)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in ./chatbot-env/lib/python3.10/site-packages (from llama-index-core==0.10.61->llama-index) (1.0.8)
# Requirement already satisfied: requests>=2.31.0 in ./chatbot-env/lib/python3.10/site-packages (from llama-index-core==0.10.61->llama-index) (2.32.3)
# Requirement already satisfied: typing-inspect>=0.8.0 in ./chatbot-env/lib/python3.10/site-packages (from llama-index-core==0.10.61->llama-index) (0.9.0)
# Requirement already satisfied: PyYAML>=6.0.1 in ./chatbot-env/lib/python3.10/site-packages (from llama-index-core==0.10.61->llama-index) (6.0.1)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in ./chatbot-env/lib/python3.10/site-packages (from llama-index-core==0.10.61->llama-index) (1.6.0)
# Requirement already satisfied: fsspec>=2023.5.0 in ./chatbot-env/lib/python3.10/site-packages (from llama-index-core==0.10.61->llama-index) (2024.6.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in ./chatbot-env/lib/python3.10/site-packages (from llama-index-core==0.10.61->llama-index) (4.66.4)
# Requirement already satisfied: SQLAlchemy[asyncio]>=1.4.49 in ./chatbot-env/lib/python3.10/site-packages (from llama-index-core==0.10.61->llama-index) (2.0.31)
# Requirement already satisfied: filelock in ./chatbot-env/lib/python3.10/site-packages (from transformers) (3.15.4)
# Requirement already satisfied: regex!=2019.12.17 in ./chatbot-env/lib/python3.10/site-packages (from transformers) (2024.7.24)
# Requirement already satisfied: safetensors>=0.4.1 in ./chatbot-env/lib/python3.10/site-packages (from transformers) (0.4.3)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in ./chatbot-env/lib/python3.10/site-packages (from transformers) (0.23.5)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in ./chatbot-env/lib/python3.10/site-packages (from transformers) (0.19.1)
# Requirement already satisfied: packaging>=20.0 in ./chatbot-env/lib/python3.10/site-packages (from transformers) (23.2)
# Requirement already satisfied: psutil in ./chatbot-env/lib/python3.10/site-packages (from accelerate) (6.0.0)
# Requirement already satisfied: torch>=1.10.0 in ./chatbot-env/lib/python3.10/site-packages (from accelerate) (2.4.0)
# Requirement already satisfied: text-generation<0.8.0,>=0.7.0 in ./chatbot-env/lib/python3.10/site-packages (from llama-index-llms-huggingface) (0.7.0)
# Requirement already satisfied: llama-cloud>=0.0.11 in ./chatbot-env/lib/python3.10/site-packages (from llama-index-indices-managed-llama-cloud>=0.2.0->llama-index) (0.0.11)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.3 in ./chatbot-env/lib/python3.10/site-packages (from llama-index-readers-file<0.2.0,>=0.1.4->llama-index) (4.12.3)
# Requirement already satisfied: striprtf<0.0.27,>=0.0.26 in ./chatbot-env/lib/python3.10/site-packages (from llama-index-readers-file<0.2.0,>=0.1.4->llama-index) (0.0.26)
# Requirement already satisfied: llama-parse>=0.4.0 in ./chatbot-env/lib/python3.10/site-packages (from llama-index-readers-llama-parse>=0.1.2->llama-index) (0.4.9)
# Requirement already satisfied: certifi>=2017.4.17 in ./chatbot-env/lib/python3.10/site-packages (from requests>=2.31.0->llama-index-core==0.10.61->llama-index) (2024.7.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./chatbot-env/lib/python3.10/site-packages (from requests>=2.31.0->llama-index-core==0.10.61->llama-index) (2.2.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./chatbot-env/lib/python3.10/site-packages (from requests>=2.31.0->llama-index-core==0.10.61->llama-index) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in ./chatbot-env/lib/python3.10/site-packages (from requests>=2.31.0->llama-index-core==0.10.61->llama-index) (3.7)
# Requirement already satisfied: pydantic<3,>2 in ./chatbot-env/lib/python3.10/site-packages (from text-generation<0.8.0,>=0.7.0->llama-index-llms-huggingface) (2.8.2)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in ./chatbot-env/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (11.4.5.107)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in ./chatbot-env/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (12.1.105)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in ./chatbot-env/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (11.0.2.54)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in ./chatbot-env/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in ./chatbot-env/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (2.20.5)
# Requirement already satisfied: sympy in ./chatbot-env/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (1.13.1)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in ./chatbot-env/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (12.1.105)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in ./chatbot-env/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (12.1.3.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in ./chatbot-env/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (12.1.105)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in ./chatbot-env/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (10.3.2.106)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in ./chatbot-env/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in ./chatbot-env/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (9.1.0.70)
# Requirement already satisfied: triton==3.0.0 in ./chatbot-env/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (3.0.0)
# Requirement already satisfied: jinja2 in ./chatbot-env/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (3.1.4)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in ./chatbot-env/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.10.0->accelerate) (12.6.20)
# Requirement already satisfied: frozenlist>=1.1.1 in ./chatbot-env/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core==0.10.61->llama-index) (1.4.1)
# Requirement already satisfied: attrs>=17.3.0 in ./chatbot-env/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core==0.10.61->llama-index) (23.2.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in ./chatbot-env/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core==0.10.61->llama-index) (4.0.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./chatbot-env/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core==0.10.61->llama-index) (6.0.5)
# Requirement already satisfied: aiosignal>=1.1.2 in ./chatbot-env/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core==0.10.61->llama-index) (1.3.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in ./chatbot-env/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core==0.10.61->llama-index) (1.9.4)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in ./chatbot-env/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core==0.10.61->llama-index) (2.3.4)
# Requirement already satisfied: soupsieve>1.2 in ./chatbot-env/lib/python3.10/site-packages (from beautifulsoup4<5.0.0,>=4.12.3->llama-index-readers-file<0.2.0,>=0.1.4->llama-index) (2.5)
# Requirement already satisfied: anyio in ./chatbot-env/lib/python3.10/site-packages (from httpx->llama-index-core==0.10.61->llama-index) (3.7.1)
# Requirement already satisfied: sniffio in ./chatbot-env/lib/python3.10/site-packages (from httpx->llama-index-core==0.10.61->llama-index) (1.3.1)
# Requirement already satisfied: httpcore==1.* in ./chatbot-env/lib/python3.10/site-packages (from httpx->llama-index-core==0.10.61->llama-index) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in ./chatbot-env/lib/python3.10/site-packages (from httpcore==1.*->httpx->llama-index-core==0.10.61->llama-index) (0.14.0)
# Requirement already satisfied: joblib in ./chatbot-env/lib/python3.10/site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core==0.10.61->llama-index) (1.4.2)
# Requirement already satisfied: click in ./chatbot-env/lib/python3.10/site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core==0.10.61->llama-index) (8.1.7)
# Requirement already satisfied: distro<2,>=1.7.0 in ./chatbot-env/lib/python3.10/site-packages (from openai>=1.1.0->llama-index-core==0.10.61->llama-index) (1.9.0)
# Requirement already satisfied: pydantic-core==2.20.1 in ./chatbot-env/lib/python3.10/site-packages (from pydantic<3,>2->text-generation<0.8.0,>=0.7.0->llama-index-llms-huggingface) (2.20.1)
# Requirement already satisfied: annotated-types>=0.4.0 in ./chatbot-env/lib/python3.10/site-packages (from pydantic<3,>2->text-generation<0.8.0,>=0.7.0->llama-index-llms-huggingface) (0.7.0)
# Requirement already satisfied: greenlet!=0.4.17 in ./chatbot-env/lib/python3.10/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core==0.10.61->llama-index) (3.0.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in ./chatbot-env/lib/python3.10/site-packages (from typing-inspect>=0.8.0->llama-index-core==0.10.61->llama-index) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in ./chatbot-env/lib/python3.10/site-packages (from dataclasses-json->llama-index-core==0.10.61->llama-index) (3.21.3)
# Requirement already satisfied: MarkupSafe>=2.0 in ./chatbot-env/lib/python3.10/site-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.5)
# Requirement already satisfied: tzdata>=2022.7 in ./chatbot-env/lib/python3.10/site-packages (from pandas->llama-index-core==0.10.61->llama-index) (2024.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./chatbot-env/lib/python3.10/site-packages (from pandas->llama-index-core==0.10.61->llama-index) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./chatbot-env/lib/python3.10/site-packages (from pandas->llama-index-core==0.10.61->llama-index) (2024.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./chatbot-env/lib/python3.10/site-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)
# Requirement already satisfied: exceptiongroup in ./chatbot-env/lib/python3.10/site-packages (from anyio->httpx->llama-index-core==0.10.61->llama-index) (1.2.2)
# Requirement already satisfied: six>=1.5 in ./chatbot-env/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->llama-index-core==0.10.61->llama-index) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from llama_index.core import VectorStoreIndex, SimpleDirectoryReader
import torch
from transformers import BitsAndBytesConfig
from llama_index.core import PromptTemplate
from llama_index.llms.huggingface import HuggingFaceLLM
from llama_index.core import ServiceContext
# from llama_index.core.response.notebook_utils import display_response

# %%
quantization_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_compute_dtype=torch.float16,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_use_double_quant=True,
)
quantization_config
# Out:
# BitsAndBytesConfig {
#   "_load_in_4bit": true,
#   "_load_in_8bit": false,
#   "bnb_4bit_compute_dtype": "float16",
#   "bnb_4bit_quant_storage": "uint8",
#   "bnb_4bit_quant_type": "nf4",
#   "bnb_4bit_use_double_quant": true,
#   "llm_int8_enable_fp32_cpu_offload": false,
#   "llm_int8_has_fp16_weight": false,
#   "llm_int8_skip_modules": null,
#   "llm_int8_threshold": 6.0,
#   "load_in_4bit": true,
#   "load_in_8bit": false,
#   "quant_method": "bitsandbytes"
# }

# %%
def messages_to_prompt(messages):
  prompt = ""
  for message in messages:
    if message.role == 'system':
      prompt += f"<|system|>\n{message.content}\n"
    elif message.role == 'user':
      prompt += f"<|user|>\n{message.content}\n"
    elif message.role == 'assistant':
      prompt += f"<|assistant|>\n{message.content}\n"
# ensure we start with a system prompt, insert blank if needed
  if not prompt.startswith("<|system|>\n"):
    prompt = "<|system|>\n\n" + prompt

  # add final assistant prompt
  prompt = prompt + "<|assistant|>\n"

  return prompt

# %%
llm = HuggingFaceLLM(
    model_name="daryl149/llama-2-7b-chat-hf",
    tokenizer_name="daryl149/llama-2-7b-chat-hf",
    query_wrapper_prompt=PromptTemplate("<|system|>\n\n<|user|>\n{query_str}\n<|assistant|>\n"),
    context_window=3900,
    max_new_tokens=256,
    # model_kwargs={"quantization_config": quantization_config},
    # tokenizer_kwargs={},
    generate_kwargs={"temperature": 0.3, "top_k": 50, "top_p": 0.95},
    messages_to_prompt=messages_to_prompt,
    device_map="auto",
)

llm
# Out:
# Downloading shards:   0%|          | 0/2 [01:03<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 llm = HuggingFaceLLM(
#       2     model_name="daryl149/llama-2-7b-chat-hf",
#       3     tokenizer_name="daryl149/llama-2-7b-chat-hf",
#       4     query_wrapper_prompt=PromptTemplate("<|system|>\n\n<|user|>\n{query_str}\n<|assistant|>\n"),
#       5     context_window=3900,
#       6     max_new_tokens=256,
#       7     # model_kwargs={"quantization_config": quantization_config},
#       8     # tokenizer_kwargs={},
#       9     generate_kwargs={"temperature": 0.3, "top_k": 50, "top_p": 0.95},
#      10     messages_to_prompt=messages_to_prompt,
#      11     device_map="auto",
#      12 )
#      14 llm
#
# File ~/ChatbotTest/chatbot-env/lib/python3.10/site-packages/llama_index/llms/huggingface/base.py:237, in HuggingFaceLLM.__init__(self, context_window, max_new_tokens, query_wrapper_prompt, tokenizer_name, model_name, model, tokenizer, device_map, stopping_ids, tokenizer_kwargs, tokenizer_outputs_to_remove, model_kwargs, generate_kwargs, is_chat_model, callback_manager, system_prompt, messages_to_prompt, completion_to_prompt, pydantic_program_mode, output_parser)
#     235 """Initialize params."""
#     236 model_kwargs = model_kwargs or {}
# --> 237 self._model = model or AutoModelForCausalLM.from_pretrained(
#     238     model_name, device_map=device_map, **model_kwargs
#     239 )
#     241 # check context_window
#     242 config_dict = self._model.config.to_dict()
#
# File ~/ChatbotTest/chatbot-env/lib/python3.10/site-packages/transformers/models/auto/auto_factory.py:564, in _BaseAutoModelClass.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     562 elif type(config) in cls._model_mapping.keys():
#     563     model_class = _get_model_class(config, cls._model_mapping)
# --> 564     return model_class.from_pretrained(
#     565         pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     566     )
#     567 raise ValueError(
#     568     f"Unrecognized configuration class {config.__class__} for this kind of AutoModel: {cls.__name__}.\n"
#     569     f"Model type should be one of {', '.join(c.__name__ for c in cls._model_mapping.keys())}."
#     570 )
#
# File ~/ChatbotTest/chatbot-env/lib/python3.10/site-packages/transformers/modeling_utils.py:3671, in PreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, *model_args, **kwargs)
#    3668 # We'll need to download and cache each checkpoint shard if the checkpoint is sharded.
#    3669 if is_sharded:
#    3670     # resolved_archive_file becomes a list of files that point to the different checkpoint shards in this case.
# -> 3671     resolved_archive_file, sharded_metadata = get_checkpoint_shard_files(
#    3672         pretrained_model_name_or_path,
#    3673         resolved_archive_file,
#    3674         cache_dir=cache_dir,
#    3675         force_download=force_download,
#    3676         proxies=proxies,
#    3677         resume_download=resume_download,
#    3678         local_files_only=local_files_only,
#    3679         token=token,
#    3680         user_agent=user_agent,
#    3681         revision=revision,
#    3682         subfolder=subfolder,
#    3683         _commit_hash=commit_hash,
#    3684     )
#    3686 if (
#    3687     is_safetensors_available()
#    3688     and isinstance(resolved_archive_file, str)
#    3689     and resolved_archive_file.endswith(".safetensors")
#    3690 ):
#    3691     with safe_open(resolved_archive_file, framework="pt") as f:
#
# File ~/ChatbotTest/chatbot-env/lib/python3.10/site-packages/transformers/utils/hub.py:1079, in get_checkpoint_shard_files(pretrained_model_name_or_path, index_filename, cache_dir, force_download, proxies, resume_download, local_files_only, token, user_agent, revision, subfolder, _commit_hash, **deprecated_kwargs)
#    1076 for shard_filename in tqdm(shard_filenames, desc="Downloading shards", disable=not show_progress_bar):
#    1077     try:
#    1078         # Load from URL
# -> 1079         cached_filename = cached_file(
#    1080             pretrained_model_name_or_path,
#    1081             shard_filename,
#    1082             cache_dir=cache_dir,
#    1083             force_download=force_download,
#    1084             proxies=proxies,
#    1085             resume_download=resume_download,
#    1086             local_files_only=local_files_only,
#    1087             token=token,
#    1088             user_agent=user_agent,
#    1089             revision=revision,
#    1090             subfolder=subfolder,
#    1091             _commit_hash=_commit_hash,
#    1092         )
#    1093     # We have already dealt with RepositoryNotFoundError and RevisionNotFoundError when getting the index, so
#    1094     # we don't have to catch them here.
#    1095     except EntryNotFoundError:
#
# File ~/ChatbotTest/chatbot-env/lib/python3.10/site-packages/transformers/utils/hub.py:402, in cached_file(path_or_repo_id, filename, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, **deprecated_kwargs)
#     399 user_agent = http_user_agent(user_agent)
#     400 try:
#     401     # Load from URL or cache if already cached
# --> 402     resolved_file = hf_hub_download(
#     403         path_or_repo_id,
#     404         filename,
#     405         subfolder=None if len(subfolder) == 0 else subfolder,
#     406         repo_type=repo_type,
#     407         revision=revision,
#     408         cache_dir=cache_dir,
#     409         user_agent=user_agent,
#     410         force_download=force_download,
#     411         proxies=proxies,
#     412         resume_download=resume_download,
#     413         token=token,
#     414         local_files_only=local_files_only,
#     415     )
#     416 except GatedRepoError as e:
#     417     resolved_file = _get_cache_file_to_return(path_or_repo_id, full_filename, cache_dir, revision)
#
# File ~/ChatbotTest/chatbot-env/lib/python3.10/site-packages/huggingface_hub/utils/_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     111 if check_use_auth_token:
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# File ~/ChatbotTest/chatbot-env/lib/python3.10/site-packages/huggingface_hub/file_download.py:1221, in hf_hub_download(repo_id, filename, subfolder, repo_type, revision, library_name, library_version, cache_dir, local_dir, user_agent, force_download, proxies, etag_timeout, token, local_files_only, headers, endpoint, legacy_cache_layout, resume_download, force_filename, local_dir_use_symlinks)
#    1202     return _hf_hub_download_to_local_dir(
#    1203         # Destination
#    1204         local_dir=local_dir,
#    (...)
#    1218         local_files_only=local_files_only,
#    1219     )
#    1220 else:
# -> 1221     return _hf_hub_download_to_cache_dir(
#    1222         # Destination
#    1223         cache_dir=cache_dir,
#    1224         # File info
#    1225         repo_id=repo_id,
#    1226         filename=filename,
#    1227         repo_type=repo_type,
#    1228         revision=revision,
#    1229         # HTTP info
#    1230         headers=headers,
#    1231         proxies=proxies,
#    1232         etag_timeout=etag_timeout,
#    1233         endpoint=endpoint,
#    1234         # Additional options
#    1235         local_files_only=local_files_only,
#    1236         force_download=force_download,
#    1237     )
#
# File ~/ChatbotTest/chatbot-env/lib/python3.10/site-packages/huggingface_hub/file_download.py:1367, in _hf_hub_download_to_cache_dir(cache_dir, repo_id, filename, repo_type, revision, headers, proxies, etag_timeout, endpoint, local_files_only, force_download)
#    1365 Path(lock_path).parent.mkdir(parents=True, exist_ok=True)
#    1366 with WeakFileLock(lock_path):
# -> 1367     _download_to_tmp_and_move(
#    1368         incomplete_path=Path(blob_path + ".incomplete"),
#    1369         destination_path=Path(blob_path),
#    1370         url_to_download=url_to_download,
#    1371         proxies=proxies,
#    1372         headers=headers,
#    1373         expected_size=expected_size,
#    1374         filename=filename,
#    1375         force_download=force_download,
#    1376     )
#    1377     _create_symlink(blob_path, pointer_path, new_blob=True)
#    1379 return pointer_path
#
# File ~/ChatbotTest/chatbot-env/lib/python3.10/site-packages/huggingface_hub/file_download.py:1884, in _download_to_tmp_and_move(incomplete_path, destination_path, url_to_download, proxies, headers, expected_size, filename, force_download)
#    1881         _check_disk_space(expected_size, incomplete_path.parent)
#    1882         _check_disk_space(expected_size, destination_path.parent)
# -> 1884     http_get(
#    1885         url_to_download,
#    1886         f,
#    1887         proxies=proxies,
#    1888         resume_size=resume_size,
#    1889         headers=headers,
#    1890         expected_size=expected_size,
#    1891     )
#    1893 logger.info(f"Download complete. Moving file to {destination_path}")
#    1894 _chmod_and_move(incomplete_path, destination_path)
#
# File ~/ChatbotTest/chatbot-env/lib/python3.10/site-packages/huggingface_hub/file_download.py:539, in http_get(url, temp_file, proxies, resume_size, headers, expected_size, displayed_filename, _nb_retries, _tqdm_bar)
#     537 new_resume_size = resume_size
#     538 try:
# --> 539     for chunk in r.iter_content(chunk_size=DOWNLOAD_CHUNK_SIZE):
#     540         if chunk:  # filter out keep-alive new chunks
#     541             progress.update(len(chunk))
#
# File ~/ChatbotTest/chatbot-env/lib/python3.10/site-packages/requests/models.py:820, in Response.iter_content.<locals>.generate()
#     818 if hasattr(self.raw, "stream"):
#     819     try:
# --> 820         yield from self.raw.stream(chunk_size, decode_content=True)
#     821     except ProtocolError as e:
#     822         raise ChunkedEncodingError(e)
#
# File ~/ChatbotTest/chatbot-env/lib/python3.10/site-packages/urllib3/response.py:1060, in HTTPResponse.stream(self, amt, decode_content)
#    1058 else:
#    1059     while not is_fp_closed(self._fp) or len(self._decoded_buffer) > 0:
# -> 1060         data = self.read(amt=amt, decode_content=decode_content)
#    1062         if data:
#    1063             yield data
#
# File ~/ChatbotTest/chatbot-env/lib/python3.10/site-packages/urllib3/response.py:949, in HTTPResponse.read(self, amt, decode_content, cache_content)
#     946     if len(self._decoded_buffer) >= amt:
#     947         return self._decoded_buffer.get(amt)
# --> 949 data = self._raw_read(amt)
#     951 flush_decoder = amt is None or (amt != 0 and not data)
#     953 if not data and len(self._decoded_buffer) == 0:
#
# File ~/ChatbotTest/chatbot-env/lib/python3.10/site-packages/urllib3/response.py:873, in HTTPResponse._raw_read(self, amt, read1)
#     870 fp_closed = getattr(self._fp, "closed", False)
#     872 with self._error_catcher():
# --> 873     data = self._fp_read(amt, read1=read1) if not fp_closed else b""
#     874     if amt is not None and amt != 0 and not data:
#     875         # Platform-specific: Buggy versions of Python.
#     876         # Close the connection when no data is returned
#    (...)
#     881         # not properly close the connection in all cases. There is
#     882         # no harm in redundantly calling close.
#     883         self._fp.close()
#
# File ~/ChatbotTest/chatbot-env/lib/python3.10/site-packages/urllib3/response.py:856, in HTTPResponse._fp_read(self, amt, read1)
#     853     return self._fp.read1(amt) if amt is not None else self._fp.read1()
#     854 else:
#     855     # StringIO doesn't like amt=None
# --> 856     return self._fp.read(amt) if amt is not None else self._fp.read()
#
# File /usr/lib/python3.10/http/client.py:466, in HTTPResponse.read(self, amt)
#     463 if self.length is not None and amt > self.length:
#     464     # clip the read to the "end of response"
#     465     amt = self.length
# --> 466 s = self.fp.read(amt)
#     467 if not s and amt:
#     468     # Ideally, we would raise IncompleteRead if the content-length
#     469     # wasn't satisfied, but it might break compatibility.
#     470     self._close_conn()
#
# File /usr/lib/python3.10/socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File /usr/lib/python3.10/ssl.py:1303, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1299     if flags != 0:
#    1300         raise ValueError(
#    1301           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1302           self.__class__)
# -> 1303     return self.read(nbytes, buffer)
#    1304 else:
#    1305     return super().recv_into(buffer, nbytes, flags)
#
# File /usr/lib/python3.10/ssl.py:1159, in SSLSocket.read(self, len, buffer)
#    1157 try:
#    1158     if buffer is not None:
# -> 1159         return self._sslobj.read(len, buffer)
#    1160     else:
#    1161         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
service_context = ServiceContext.from_defaults(llm=llm, embed_model="local:BAAI/bge-small-en-v1.5")
service_context

# %%
vector_index = VectorStoreIndex.from_documents(documents, service_context=service_context)
vector_index
